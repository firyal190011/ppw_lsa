# %% [markdown]
# # Latent Semantic Analysis (LSA)

# %% [markdown]
# Latent Semantic Analysis (LSA) merupakan sebuah metode yang memanfaatkan model statistik matematis untuk menganalisa struktur semantik suatu teks. LSA bisa digunakan untuk menilai esai dengan mengkonversikan esai menjadi matriks-matriks yang diberi nilai pada masing-masing term untuk dicari kesamaan dengan term referensi

# %% [markdown]
# # Crawling data
# Crawlling merupakan proses pengambilan data yang tersedia secara online untuk umum. Proses pengambilan data informasi pada halaman menggunakan URL (Uniform Resource Locator). URL ini akan menjadi acuan untuk mencari semua hyperlink yang ada pada website. Kemudian dilakukan indexing untuk mencari kata dalam dokumen pada setiap link yang ada. Lalu jika, menyertakan API (Application Programming Interface) dapat melakukan penambangan dataset yang lebih besar. Selain itu, dengan API kita dapat mengumpulkan data lebih spesifik sesuai dengan link URL yang ada tanpa harus mengetahui element HTML pada sebuah website.

# %% [markdown]
# ## Instalasi Scrapy
# Untuk menginstall scrapy dapat menggnakan perintah pip di Command Prompt berikut:

# %%
pip install scrapy

# %% [markdown]
# ## Membuat File Scrapy
# Setelah selesai menginstall Scrapy, maka buat file scrapy baru dengan kode:

# %%
scrapy startproject namaproject

# %% [markdown]
# ## Menjalankan Spyder baru
# Yang harus dilakukan, masuk ke dalam projectscrapy kemudian membuat spider baru dengan kode:

# %%
cd nama project

# %% [markdown]
# Setelah menjalankan spyder baru, tuliskan command yang isinya nama file dan alamat website yang akan diambil datanya agar lebih mudah saat akan membuat.

# %%
scrapy genspider example example.com

# %% [markdown]
# ## Menulis Program Scapper
# Setelah itu, pada pembuatan spyder file yang tadi telah dibuat telah tersedia dengan nama file yang telah dibuat.
#
# Pada file yang telah dibuat akan ada code untuk melakukan scraping yang dapat diubah sesuai keinginan

# %%
import scrapy
class QuotesSpider(scrapy.Spider):
    name = "quotes"

    def start_requests(self):
        urls = [
            'https://pta.trunojoyo.ac.id/welcome/detail/160411100077',
            'https://pta.trunojoyo.ac.id/welcome/detail/160211100071',
            'https://pta.trunojoyo.ac.id/welcome/detail/160531100046',
            'https://pta.trunojoyo.ac.id/welcome/detail/160521100004',
            'https://pta.trunojoyo.ac.id/welcome/detail/160541100008',
            'https://pta.trunojoyo.ac.id/welcome/detail/150721100036',
            'https://pta.trunojoyo.ac.id/welcome/detail/160721100026',
            'https://pta.trunojoyo.ac.id/welcome/detail/160421100099',
            'https://pta.trunojoyo.ac.id/welcome/detail/150721100026',
            'https://pta.trunojoyo.ac.id/welcome/detail/160521100008',
            'https://pta.trunojoyo.ac.id/welcome/detail/160421100169',
            'https://pta.trunojoyo.ac.id/welcome/detail/160211100041',
            'https://pta.trunojoyo.ac.id/welcome/detail/160311100017',
            'https://pta.trunojoyo.ac.id/welcome/detail/130611100192',
            'https://pta.trunojoyo.ac.id/welcome/detail/160521100043'
        ]
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
        # print(response.url)
        yield {
            'judul': response.css('#content_journal > ul > li > div:nth-child(2) > a::text').extract(),
            'penulis': response.css('#content_journal > ul > li > div:nth-child(2) > div:nth-child(2) > span::text').extract(),
            'dosen_pembimbing_1': response.css('#content_journal > ul > li > div:nth-child(2) > div:nth-child(3) > span::text').extract(),
            'dosen_pembimbing_2': response.css('#content_journal > ul > li > div:nth-child(2) > div:nth-child(4) > span::text').extract(),
            'abstrak': response.css('#content_journal > ul > li > div:nth-child(4) > div:nth-child(2) > p::text').extract(),
        }
        # content_journal > ul > li:nth-child(1) > div:nth-child(1) > a
        # content_journal > ul > li:nth-child(1) > div:nth-child(1) > a

# %% [markdown]
# ## Menjalankan File Spider
# Pertama, masuk kedalam direktori spider dulu. setelah itu, jalankan spider dengan command

# %%
scrapy runspider namafile.py

# %% [markdown]
# ## Menyimpan data kedalam csv
# Data yang telah diambil dari suatu web dapat disimpan dengan kode:

# %%
scrapy crawl namafile -O namafileyangdiinginkan.xlsx

# %% [markdown]
# # Preprocessing data
# Preprocessing data adalah tahapan perbersihan data dari suatu kalimat atau kata, link, atau hal –hal yang tidak diperlukan untuk melakukan analisis sentiment. Dataset yang diperoleh dari proses crawling masih berbentuk kata atau kalimat yang tidak beraturan atau tidak terstruktur, sehingga membutuhkan proses yang disebut preprocessing data agar menghasilkan data yang bersih supaya mempermudah proses analisis. Lalu pada Preprocessing sendiri melibatkan validasi dan imputasi data. Tujuan dari validasi adalah untuk menilai tingkat kelengkapan dan akurasi data yang tersaring. Preprocessing data sangat penting karena kesalahan, redundan, missing value, dan data yang tidak konsisten menyebabkan berkurangnya akurasi hasil analisis. Jadi, sebelum mengolah data, kita harus memastikan bahwa data yang akan kita gunakan merupakan data "bersih". Ada beberapa cara yang bisa digunakan untuk membersihkan data, tergantung dari jenis masalah yang ada dalam kumpulan data. Adapun tahapan preprocessing data terdiri dari Cleaning data, Case Folding, Tokenizing, Stopword, dan Stemming.

# %% [markdown]
# ## Installasi library
# lakukan installasi library yang diperlukan, jika telah terinstall maka langsung panggil saja

# %%
# !pip install nltk
# !pip install numpy
# !pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk) (4.64.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk) (2022.6.2)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk) (1.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.21.6)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/omw-1.4.zip.
# True

# %% [markdown]
# ## Import library yang digunakan
# memanggil library-library yang digunakan

# %%
# data visualisation and manipulation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
#configure
# sets matplotlib to inline and displays graphs below the corressponding cell.
# %matplotlib inline  
style.use('fivethirtyeight')
sns.set(style='whitegrid',color_codes=True)

#import nltk
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize,sent_tokenize

#preprocessing
from nltk.corpus import stopwords  #stopwords
from nltk import word_tokenize,sent_tokenize # tokenizing
from nltk.stem import PorterStemmer,LancasterStemmer  # using the Porter Stemmer and Lancaster Stemmer and others
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer  # lammatizer from WordNet

# for named entity recognition (NER)
from nltk import ne_chunk

# vectorizers for creating the document-term-matrix (DTM)
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer

#stop-words
stop_words=set(nltk.corpus.stopwords.words('english'))

# %% [markdown]
# ## Data set
# berikut data yang digunakan pada program saat ini

# %%
df=pd.read_csv('jurnal.csv')

# %%
df.head(10)
# Out:
#                                                Judul  \
# 0  APLIKASI DAN DESAIN MODEL DECISION AID PELANGG...
# 1  ANALISA DATA ANTARAN POS EXPRESS MENGGUNAKAN\r...
# 2  Model Penjualan Produk Unggulan Batik Khas Pam...
# 3  PENERAPAN METODE ANALYTICAL HIERARCHY PROCESS ...
# 4  PENGELOMPOKAN KUALITAS KELAS PADA SISWA MENGGU...
# 5  SISTEM PENDUKUNG KEPUTUSAN PEMILIHAN KARYAWAN ...
# 6  Deteksi Manusia Menggunakan Histogram of Orien...
# 7  KLASIFIKASI STATUS GIZI BALITA MENGGUNAKAN KOH...
# 8  Aplikasi Penilaian Kinerja dengan Metodologi C...
# 9  APLIKASI CITRA MOSAIC PANORAMIC MENGGUNAKAN ME...
#
#                          Penulis                            Dosbing_1  \
# 0             Ardiyanto Setiawan  Moch. Kautsar Sophan, S.Kom., M.MT.
# 1          siti murtasiyah warda    Bain Khusnul Khotimah.,S.T.,M.Kom
# 2                  Murni Rotifah    Moch. Kautsar Sophan, S.Kom, M.MT
# 3                       Helyatin           Bain Khusnul K, S.T.,M.Kom
# 4                        Hamiyah             Bain Khusnul K,ST.,M.Kom
# 5            Catur Ngesti Waluyo                  Mula'ab,S.Si.,M.Kom
# 6  R.A. Uluwiyah Nur Oktavianis     Dr. Indah Agustien, S.Kom., M.Kom
# 7                  Uhty Zunairoh  Bain Khusnul Khotimah, S.T., M.Kom.
# 8                   Luthfi Zahro   Moch. Kautsar Sophan, S.Kom., M.MT
# 9                Gendra Budiarti                Eza Rahmanita, ST, MT
#
#                                  Dosbing_2  \
# 0     eni Kustiyah Ningsih, S.Kom., M.Kom.
# 1               irli Irhamni, S.T., M.Kom.
# 2  ain Khusnul Khotimah, S.T., M.Kom
# 3             ndharini Dwi C, S.Kom.,M.Kom
# 4                 irli Irhamni, ST, M. Kom
# 5                    iza Alfita, S.T., M.T
# 6               ri Kusumaningsih, S.T, M.T
# 7                  eri Rachmad, S.T., M.T.
# 8              r. Rachmad Hidayat, ST., MT
# 9            eidya Koeshardianto, S.Si, MT
#
#                                         Abstrak_indo
# 0  Toko Batik Tulis Madura merupakan salah satu t...
# 1  PT. Pos Indonesia (Persero) merupakan salah sa...
# 2  Kabupaten Pamekasan merupakan salah satu pusat...
# 3  Pemilihan  supplier merupakan salah satu isu p...
# 4  ABSTRAK\r\nData yang terdapat pada SMA Wachid ...
# 5  Sumber daya manusia mutlak dibutuhkan untuk ke...
# 6  Deteksi manusia merupakan  suatu aplikasi yang...
# 7  Aplikasi klasifikasi status gizi balita ini di...
# 8  Setiap perusahaan mengharapkan adanya hubungan...
# 9  Sebuah citra banyak diterapkan dalam berbagai ...

# %% [markdown]
# ## Drop data yang tidak digunakan

# %%
df.drop(['Judul','Penulis', 'Dosbing_1', 'Dosbing_2'],axis=1, inplace=True)

# %%
df.head(30)
# Out:
#                                          Abstrak_indo
# 0   Toko Batik Tulis Madura merupakan salah satu t...
# 1   PT. Pos Indonesia (Persero) merupakan salah sa...
# 2   Kabupaten Pamekasan merupakan salah satu pusat...
# 3   Pemilihan  supplier merupakan salah satu isu p...
# 4   ABSTRAK\r\nData yang terdapat pada SMA Wachid ...
# 5   Sumber daya manusia mutlak dibutuhkan untuk ke...
# 6   Deteksi manusia merupakan  suatu aplikasi yang...
# 7   Aplikasi klasifikasi status gizi balita ini di...
# 8   Setiap perusahaan mengharapkan adanya hubungan...
# 9   Sebuah citra banyak diterapkan dalam berbagai ...
# 10  Penggunaan teknologi mobile saat ini sangat ma...
# 11  Perkembangan game yang semakin pesat, memberik...
# 12  Teknologi mobile game beroperating system open...
# 13  Gerak pekerja ada pada game yang memiliki genr...
# 14  Sistem  informasi  akademik  (SIAKAD) merupaka...
# 15  Teknik kalibrasi sangat berpengaruh terhadap p...
# 16  Berjalannya koneksi jaringan komputer dengan l...
# 17  Malaria disebabkan oleh intraseluler parasit b...
# 18  Web server adalah sebuah perangkat lunak serve...
# 19  Penjadwalan  kuliah  di  Perguruan  Tinggi  me...
# 20  Seiring perkembangan teknologi yang ada diduni...
# 21  Citra senyum merupakan salah satu fitur biomet...
# 22  Kebutuhan pencarian data pada internet yang ce...
# 23  Penelitian ini membahas tentang perancangan si...
# 24  Dengan prediksi yang baik, dapat dibuat rencan...
# 25  Menurut pemetaan yang dilakukan oleh Tim Nasio...
# 26  Diagnosa penyakit mata dengan sistem informasi...
# 27  Berawal dari permintaan akan Straw (sperma bek...
# 28  Pengetahuan tentang bahasa Inggris pada jaman ...
# 29  Sistem pengenalan wajah adalah suatu sistem un...

# %% [markdown]
# ## Remove angka
# pada proses ini penghapusan angka dan tanda-tanda baca yang ada pada data

# %%
import string 
import re

def remove(text):
    return re.sub(r"\d+","",text)

# %%
df['Abstrak_indo_remove']=df['Abstrak_indo'].apply(remove)
df.head()
# Out:
#                                         Abstrak_indo  \
# 0  Toko Batik Tulis Madura merupakan salah satu t...
# 1  PT. Pos Indonesia (Persero) merupakan salah sa...
# 2  Kabupaten Pamekasan merupakan salah satu pusat...
# 3  Pemilihan  supplier merupakan salah satu isu p...
# 4  ABSTRAK\r\nData yang terdapat pada SMA Wachid ...
#
#                                  Abstrak_indo_remove
# 0  Toko Batik Tulis Madura merupakan salah satu t...
# 1  PT. Pos Indonesia (Persero) merupakan salah sa...
# 2  Kabupaten Pamekasan merupakan salah satu pusat...
# 3  Pemilihan  supplier merupakan salah satu isu p...
# 4  ABSTRAK\r\nData yang terdapat pada SMA Wachid ...

# %% [markdown]
# ## Cleansing data
#
#   Data cleansing atau yang disebut juga dengan data scrubbing merupakan suatu proses analisa mengenai kualitas dari data dengan mengubah. Bisa juga pengelola mengoreksi ataupun menghapus data tersebut. Data yang dibersihkan tersebut adalah data yang salah, rusak, tidak akurat, tidak lengkap dan salah format. Selain itu, Cleaning data adalah proses menghilangkan atau  menghapus  data  dari  suatu  kalimat  yang  memiliki unsur, seperti username (@username), hastag (#), URL, angka, kalimat yang redundance,emoticon (:@, :D ), dan tanda baca  yang tidak diperlukan pada saat proses analisis sentiment. Pada proses cleaningini pun juga terjadi proses perubahan data ke lowercase.

# %%
def clean_text(headline):
  le=WordNetLemmatizer()
  word_tokens=word_tokenize(headline)
  tokens=[le.lemmatize(w) for w in word_tokens if w not in stop_words and len(w)>3]
  cleaned_text=" ".join(tokens)
  return cleaned_text

# %%
# time taking
df['Abstrak_indo_cleaned']=df['Abstrak_indo_remove'].apply(clean_text)

# %%
df.head()
# Out:
#                                         Abstrak_indo  \
# 0  Toko Batik Tulis Madura merupakan salah satu t...
# 1  PT. Pos Indonesia (Persero) merupakan salah sa...
# 2  Kabupaten Pamekasan merupakan salah satu pusat...
# 3  Pemilihan  supplier merupakan salah satu isu p...
# 4  ABSTRAK\r\nData yang terdapat pada SMA Wachid ...
#
#                                  Abstrak_indo_remove  \
# 0  Toko Batik Tulis Madura merupakan salah satu t...
# 1  PT. Pos Indonesia (Persero) merupakan salah sa...
# 2  Kabupaten Pamekasan merupakan salah satu pusat...
# 3  Pemilihan  supplier merupakan salah satu isu p...
# 4  ABSTRAK\r\nData yang terdapat pada SMA Wachid ...
#
#                                 Abstrak_indo_cleaned
# 0  Toko Batik Tulis Madura merupakan salah satu t...
# 1  Indonesia Persero merupakan salah satu perusah...
# 2  Kabupaten Pamekasan merupakan salah satu pusat...
# 3  Pemilihan supplier merupakan salah satu pentin...
# 4  ABSTRAK Data yang terdapat pada Wachid Hasyim ...

# %% [markdown]
# ## Menghapus data yang tidak dibutuhkan
# hal ini bertujuan agar menggunakan data yang telah di cleansing data

# %%
df.drop(['Abstrak_indo', 'Abstrak_indo_remove'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                                 Abstrak_indo_cleaned
# 0  Toko Batik Tulis Madura merupakan salah satu t...
# 1  Indonesia Persero merupakan salah satu perusah...
# 2  Kabupaten Pamekasan merupakan salah satu pusat...
# 3  Pemilihan supplier merupakan salah satu pentin...
# 4  ABSTRAK Data yang terdapat pada Wachid Hasyim ...

# %%
df['Abstrak_indo_cleaned'][0]
# Out:
# 'Toko Batik Tulis Madura merupakan salah satu toko yang telah beroperasi sejak tahun dengan menggunakan website e-commerce Walau telah menggunakan model e-commerce website tersebut memiliki kekurangan yaitu belum fitur rekomndasi untuk memudahkan konsumen mencari barang yang ingin dibelinya Penelitian bertujuan membuat rekomendasi dengan decision untuk membantu pelanggan dalam memilih produk website Toko Batik Tulis Madura Teknik pengumpulan analis data terdiri dari Studi Literatur yang berhubungan dengan decision multi criterion Observasi dilakukan terhadap website Toko Batik Tulis Madura Interview dilakukan kepada pemilik website Toko Batik Tulis Madura Pembuatan implementasi pada Penelitian menggunakan model waterfall Jenis decision yang akan diimplementasikan adalah Multi Criteria Filtering Metode pembobotan yang digunakan pada Multi Criteria Filtering yaitu Decision Matrix Hasil ujicoba dengan jumlah sample percobaan sebanyak kali data perconbaan pencarian presentase akurasi adalah error adalah Hasil kelayakan dari beberapa kuisoner dihasilkan bahwa performa yang dimiliki tool cukup baik tool layak untuk diintegrasikan serta digunakan dalam website e-commerce Kata Kunci Decision Multi Criteria Filtering'

# %% [markdown]
# ## TF-IDF
# TF — IDF adalah suatu metode algoritma yang berguna untuk menghitung bobot setiap kata yang umum digunakan. Metode ini juga terkenal efisien, mudah dan memiliki hasil yang akurat. Metode ini akan menghitung nilai Term Frequency (TF) dan Inverse Document Frequency (IDF) pada setiap token (kata) di setiap dokumen dalam korpus. Secara sederhana, metode TF-IDF digunakan untuk mengetahui berapa sering suatu kata muncul di dalam dokumen.

# %% [markdown]
# Term Frequency (TF) yaitu pembobotan/weight setiap kata (term) pada suatu dokumen berdasarkan jumlah kemunculannya dalam dokumen tersebut. Semakin besar jumlah kemunculan suatu kata dalam dokumen, maka semakin besar pula bobot yang diberikan (TF Tinggi) jadi nilai tertinggi merupakan  jumlah kemunculan/frekuensi.
#
# Setelah menentukan Tf maka selanjutnya kita tentukan nilai IDF nya dapat dihitung dengan rumus :
# $$
# \begin{gathered}
# Tf-Idf=t f_{i j} * i d f_{j} \\
# Tf-Idf=t f_{i j} * \log \left(\frac{D}{d f}\right)
# \end{gathered}
# $$
#
# Catatan
#
# Df = jumlah dokumen yang didalamnya memuat term tertentu
#
# D = Jumlah Dokumen yang di perbandingkan

# %%
vect =TfidfVectorizer(stop_words=stop_words,max_features=1000) 
# to play with. min_df,max_df,max_features etc...

# %%
vect_text=vect.fit_transform(df['Abstrak_indo_cleaned'])

# %%
print(vect_text.shape)
print(vect_text)
# Out:
# (60, 1000)
#   (0, 953)	0.3465491324939889
#   (0, 60)	0.22934421249875928
#   (0, 966)	0.2573610461627056
#   (0, 422)	0.21869270668595223
#   (0, 533)	0.027371681178565355
#   (0, 768)	0.029533812325534276
#   (0, 775)	0.030119444797511292
#   (0, 998)	0.10364702080532326
#   (0, 900)	0.07139038976278697
#   (0, 798)	0.06930982649879779
#   (0, 886)	0.052366488166568435
#   (0, 150)	0.07140149430024889
#   (0, 512)	0.06758881172864305
#   (0, 992)	0.4158589589927867
#   (0, 129)	0.20792947949639334
#   (0, 544)	0.11467210624937964
#   (0, 927)	0.027371681178565355
#   (0, 474)	0.030725629923272116
#   (0, 996)	0.06401161669042994
#   (0, 67)	0.052366488166568435
#   (0, 236)	0.04851179411562884
#   (0, 975)	0.05355112072518667
#   (0, 483)	0.05467317667148806
#   (0, 380)	0.0643402615406764
#   (0, 488)	0.05467317667148806
#   :	:
#   (59, 256)	0.5377443307883311
#   (59, 497)	0.038545881537060143
#   (59, 833)	0.03653802563183533
#   (59, 2)	0.03653802563183533
#   (59, 687)	0.0643643400729009
#   (59, 51)	0.03393091155175158
#   (59, 963)	0.05974937008759234
#   (59, 667)	0.0561697212657046
#   (59, 517)	0.05974937008759234
#   (59, 438)	0.08704271811778337
#   (59, 910)	0.0643643400729009
#   (59, 186)	0.04505031640872809
#   (59, 830)	0.05077206384596112
#   (59, 211)	0.05324493521592439
#   (59, 72)	0.0561697212657046
#   (59, 481)	0.05324493521592439
#   (59, 366)	0.0561697212657046
#   (59, 601)	0.2987468504379617
#   (59, 767)	0.05324493521592439
#   (59, 635)	0.21297974086369756
#   (59, 313)	0.05077206384596112
#   (59, 764)	0.0561697212657046
#   (59, 425)	0.0643643400729009
#   (59, 556)	0.21260632483370653
#   (59, 912)	0.1417375498891377

# %%
vect.get_feature_names()
# Out:
# c:\Users\ASUS\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['abstrak',
#  'adalah',
#  'adanya',
#  'administrator',
#  'agar',
#  'akademik',
#  'akan',
#  'akhir',
#  'aksara',
#  'akurasi',
#  'akurat',
#  'algoritma',
#  'alternatif',
#  'analisa',
#  'analisis',
#  'analysis',
#  'analytic',
#  'android',
#  'angular',
#  'animasi',
#  'antar',
#  'antara',
#  'apabila',
#  'aplikasi',
#  'arah',
#  'arosbaya',
#  'arsitektur',
#  'asesoris',
#  'aspek',
#  'atas',
#  'atau',
#  'augmented',
#  'awal',
#  'background',
#  'backpropagation',
#  'badan',
#  'bagaimana',
#  'bagi',
#  'bagian',
#  'bahan',
#  'bahari',
#  'bahasa',
#  'bahkan',
#  'bahwa',
#  'baik',
#  'baku',
#  'bali',
#  'balita',
#  'bangkalan',
#  'bangsa',
#  'bantuan',
#  'banyak',
#  'banyaknya',
#  'barang',
#  'baru',
#  'base',
#  'basic',
#  'basis',
#  'basisdata',
#  'batasan',
#  'batik',
#  'bawa',
#  'bayes',
#  'beasiswa',
#  'beberapa',
#  'bekerja',
#  'belajar',
#  'belum',
#  'benedict',
#  'bentuk',
#  'berada',
#  'beragam',
#  'berapa',
#  'berasal',
#  'berbagai',
#  'berbasis',
#  'berbeda',
#  'berbentuk',
#  'berdasarkan',
#  'berfokus',
#  'berfungsi',
#  'bergerak',
#  'berhak',
#  'berhasil',
#  'berikutnya',
#  'berjalan',
#  'berjalannya',
#  'berjumlah',
#  'berkaitan',
#  'berkembang',
#  'berkesesuaian',
#  'berprestasi',
#  'bersifat',
#  'berstatus',
#  'bertujuan',
#  'berupa',
#  'berwarna',
#  'besar',
#  'biasa',
#  'biaya',
#  'bidang',
#  'bila',
#  'biometrik',
#  'biometrika',
#  'bisa',
#  'bisnis',
#  'bobot',
#  'bold',
#  'browser',
#  'budaya',
#  'bulan',
#  'bumi',
#  'canberra',
#  'canny',
#  'cara',
#  'carakan',
#  'centroid',
#  'cepat',
#  'chain',
#  'cipherteks',
#  'cirebon',
#  'ciri',
#  'citra',
#  'class',
#  'classifier',
#  'client',
#  'cluster',
#  'clustering',
#  'coba',
#  'commerce',
#  'component',
#  'computer',
#  'corepoint',
#  'criteria',
#  'cukup',
#  'daerah',
#  'dahulu',
#  'dalam',
#  'dapat',
#  'darah',
#  'dari',
#  'dasar',
#  'dasarnya',
#  'data',
#  'database',
#  'datang',
#  'daya',
#  'decision',
#  'delapan',
#  'demikian',
#  'dengan',
#  'depth',
#  'deteksi',
#  'development',
#  'diagnosa',
#  'diambil',
#  'diantaranya',
#  'dibagi',
#  'dibahas',
#  'dibandingkan',
#  'dibangun',
#  'dibentuk',
#  'diberikan',
#  'dibuat',
#  'dibuatlah',
#  'dibuktikan',
#  'dibutuhkan',
#  'dicapai',
#  'dicari',
#  'didalam',
#  'didapat',
#  'didapatkan',
#  'didasarkan',
#  'didefinisikan',
#  'diet',
#  'digunakan',
#  'diharapkan',
#  'dihitung',
#  'diimplementasikan',
#  'diinputkan',
#  'dijadikan',
#  'dikarenakan',
#  'dikembangkan',
#  'diketahui',
#  'dilakukan',
#  'dilihat',
#  'dimana',
#  'dimanfaatkan',
#  'dimensional',
#  'dimiliki',
#  'dinas',
#  'diperlukan',
#  'diperoleh',
#  'dipilih',
#  'diproses',
#  'direction',
#  'diri',
#  'disebabkan',
#  'disebut',
#  'disimpan',
#  'distance',
#  'ditampilkan',
#  'diteliti',
#  'ditentukan',
#  'diterapkan',
#  'ditetapkan',
#  'diuji',
#  'dokter',
#  'dokumen',
#  'dunia',
#  'efektif',
#  'efisien',
#  'ekstraksi',
#  'empat',
#  'engine',
#  'engineering',
#  'enkripsi',
#  'enterprise',
#  'epoch',
#  'epoh',
#  'error',
#  'euclidean',
#  'evaluasi',
#  'exponential',
#  'express',
#  'fahp',
#  'faktor',
#  'fakultas',
#  'fanp',
#  'feature',
#  'fighting',
#  'filtering',
#  'fine',
#  'fingerprint',
#  'finite',
#  'first',
#  'fitur',
#  'flartoolkit',
#  'fmop',
#  'font',
#  'forward',
#  'function',
#  'fungsi',
#  'fuzzy',
#  'gambar',
#  'game',
#  'gangguan',
#  'gari',
#  'gateway',
#  'gejala',
#  'genetika',
#  'genre',
#  'geografis',
#  'geometry',
#  'gerak',
#  'gerakan',
#  'gizi',
#  'gldm',
#  'global',
#  'google',
#  'government',
#  'gradient',
#  'gram',
#  'gudang',
#  'gunakan',
#  'haar',
#  'halaman',
#  'hanya',
#  'hari',
#  'harus',
#  'hasil',
#  'hasilnya',
#  'hasyim',
#  'hierarchy',
#  'histogram',
#  'html',
#  'http',
#  'hubungan',
#  'hujan',
#  'huruf',
#  'ideal',
#  'identifikasi',
#  'identitas',
#  'implementasi',
#  'indeks',
#  'indikator',
#  'indonesia',
#  'industri',
#  'info',
#  'informasi',
#  'informatika',
#  'inggris',
#  'ingin',
#  'inilah',
#  'instansi',
#  'intelegent',
#  'interaktif',
#  'interface',
#  'internet',
#  'inti',
#  'intinya',
#  'invariant',
#  'iptables',
#  'italic',
#  'jabatan',
#  'jadwal',
#  'jarak',
#  'jari',
#  'jaringan',
#  'jauh',
#  'java',
#  'jelas',
#  'jenis',
#  'jika',
#  'juga',
#  'jumlah',
#  'jurusan',
#  'kabupaten',
#  'kalangan',
#  'kali',
#  'kalibrasi',
#  'kalori',
#  'kamera',
#  'kantor',
#  'karakter',
#  'karakteristik',
#  'karapan',
#  'karena',
#  'karya',
#  'karyawan',
#  'kasus',
#  'kata',
#  'keakuratan',
#  'keamanan',
#  'kebutuhan',
#  'kecamatan',
#  'kecepatan',
#  'kecerdasan',
#  'kecil',
#  'kedalam',
#  'kegiatan',
#  'kehidupan',
#  'kelas',
#  'kelebihan',
#  'kelompok',
#  'kemajuan',
#  'kemampuan',
#  'kembali',
#  'kemiripan',
#  'kemiskinan',
#  'kemudian',
#  'kemungkinan',
#  'kendala',
#  'kepada',
#  'kepegawaian',
#  'kepentingan',
#  'keputusan',
#  'keragaman',
#  'kerapan',
#  'kerja',
#  'kesalahan',
#  'kesamaan',
#  'kesejahteraan',
#  'kesejahteraannya',
#  'keseluruhan',
#  'kesesuaian',
#  'kesimpulan',
#  'kesulitan',
#  'ketika',
#  'keuntungan',
#  'keypoint',
#  'khas',
#  'khususnya',
#  'kinerja',
#  'klasifikasi',
#  'kode',
#  'kompleks',
#  'komputer',
#  'koneksi',
#  'konsep',
#  'konsumen',
#  'konteks',
#  'kontrol',
#  'korespondensi',
#  'kriteria',
#  'kromatin',
#  'kualitas',
#  'kuliah',
#  'kunci',
#  'kurang',
#  'lahan',
#  'lain',
#  'lakukan',
#  'lama',
#  'lancar',
#  'langkah',
#  'lantai',
#  'lapangan',
#  'latent',
#  'laut',
#  'lawan',
#  'layak',
#  'layanan',
#  'lazim',
#  'learning',
#  'least',
#  'lebih',
#  'lembut',
#  'level',
#  'leveling',
#  'library',
#  'life',
#  'lima',
#  'linear',
#  'lintasan',
#  'lokal',
#  'lokasi',
#  'luar',
#  'luas',
#  'lunak',
#  'macam',
#  'machine',
#  'madura',
#  'mahasiswa',
#  'maka',
#  'makanan',
#  'maksimal',
#  'malaria',
#  'mamdani',
#  'mampu',
#  'mana',
#  'manajemen',
#  'mandiri',
#  'manual',
#  'manusia',
#  'mape',
#  'maps',
#  'masa',
#  'masalah',
#  'masih',
#  'masing',
#  'masukan',
#  'masyarakat',
#  'mata',
#  'matakuliah',
#  'matematika',
#  'materi',
#  'matrik',
#  'matrix',
#  'maupun',
#  'maya',
#  'maze',
#  'mcdm',
#  'mean',
#  'means',
#  'measure',
#  'medium',
#  'melakukan',
#  'melalui',
#  'melihat',
#  'memahami',
#  'memaksimalkan',
#  'memanfaatkan',
#  'membahas',
#  'membandingkan',
#  'membangun',
#  'membantu',
#  'memberikan',
#  'membuat',
#  'membutuhkan',
#  'memecahkan',
#  'memenuhi',
#  'memerlukan',
#  'memilih',
#  'memiliki',
#  'mempercepat',
#  'memperhatikan',
#  'memperkirakan',
#  'mempermudah',
#  'memperoleh',
#  'mempertahankan',
#  'memprediksi',
#  'mempunyai',
#  'memudahkan',
#  'memungkinkan',
#  'menangani',
#  'menarik',
#  'mencapai',
#  'mencari',
#  'mencoba',
#  'mencuri',
#  'mendapat',
#  'mendapatkan',
#  'mendekripsi',
#  'mendeteksi',
#  'mendukung',
#  'menemukan',
#  'menentukan',
#  'menerapkan',
#  'menerima',
#  'menetapkan',
#  'mengakibatkan',
#  'mengalami',
#  'mengambil',
#  'menganalisa',
#  'mengatasi',
#  'mengelompokan',
#  'mengembangkan',
#  'mengenai',
#  'mengenkripsi',
#  'mengerjakan',
#  'mengetahui',
#  'menggunakan',
#  'menghasilkan',
#  'mengidentifikasi',
#  'mengimplementasikan',
#  'mengirimkan',
#  'mengontrol',
#  'mengukur',
#  'meningkatkan',
#  'meningkatnya',
#  'menjadi',
#  'menjadikan',
#  'menjaga',
#  'mentah',
#  'menu',
#  'menunjukkan',
#  'menyebabkan',
#  'menyeleksi',
#  'menyelesaikan',
#  'merah',
#  'meramalkan',
#  'merepresentasikan',
#  'merupakan',
#  'mesin',
#  'message',
#  'metode',
#  'metodologi',
#  'minggu',
#  'minimal',
#  'minimnya',
#  'mirip',
#  'mitra',
#  'mobile',
#  'model',
#  'modified',
#  'monitoring',
#  'morfologi',
#  'mosaic',
#  'mudah',
#  'multi',
#  'muncul',
#  'mutlak',
#  'naive',
#  'namun',
#  'nantinya',
#  'naïve',
#  'negara',
#  'network',
#  'neural',
#  'nilai',
#  'nn',
#  'node',
#  'nomor',
#  'normal',
#  'normalisasi',
#  'nyata',
#  'obat',
#  'objective',
#  'objek',
#  'obyek',
#  'obyektif',
#  'oldinary',
#  'oleh',
#  'online',
#  'ontologi',
#  'operasi',
#  'optimal',
#  'optimasi',
#  'optimiztion',
#  'orang',
#  'order',
#  'ordered',
#  'organisasi',
#  'organizing',
#  'oriented',
#  'otomatis',
#  'pada',
#  'padatnya',
#  'pakar',
#  'paling',
#  'pamekasan',
#  'panorama',
#  'panoramic',
#  'para',
#  'parameter',
#  'parasit',
#  'part',
#  'particle',
#  'pasang',
#  'pasar',
#  'pasien',
#  'pekalongan',
#  'pekerja',
#  'pelajaran',
#  'pelanggan',
#  'pelanggannya',
#  'pelatihan',
#  'pelayanan',
#  'pelevelan',
#  'pemain',
#  'pemanfaatan',
#  'pembangunan',
#  'pembelajaran',
#  'pembelian',
#  'pembentukan',
#  'pembobotan',
#  'pembuatan',
#  'pemenang',
#  'pemerintah',
#  'pemetaan',
#  'pemilihan',
#  'peminat',
#  'pemrograman',
#  'pemrosesan',
#  'penambahan',
#  'penanggulangan',
#  'pencarian',
#  'pencocokan',
#  'pendekatan',
#  'pendeteksian',
#  'pendidikan',
#  'penduduk',
#  'pendukung',
#  'penelitian',
#  'penentuan',
#  'penerapan',
#  'penerima',
#  'pengalaman',
#  'pengambilan',
#  'pengawasan',
#  'pengelolaan',
#  'pengelompokan',
#  'pengembang',
#  'pengembangan',
#  'pengenalan',
#  'pengentasan',
#  'pengetahuan',
#  'penggabungan',
#  'pengguna',
#  'penggunaan',
#  'penggunanya',
#  'pengiriman',
#  'pengklasifikasian',
#  'pengolahan',
#  'pengujian',
#  'pengukuran',
#  'pengumpulan',
#  'penilaian',
#  'peningkatan',
#  'penjadwalan',
#  'penjiplakan',
#  'penjualan',
#  'penting',
#  'penulis',
#  'penurunan',
#  'penyajian',
#  'penyakit',
#  'penyampaian',
#  'penyediaan',
#  'penyusunan',
#  'penyusupan',
#  'peramalan',
#  'peranan',
#  'perancangan',
#  'perangkat',
#  'perangkingan',
#  'peraturan',
#  'perawatan',
#  'perbandingan',
#  'perbedaan',
#  'percobaan',
#  'perdagangan',
#  'perencanaan',
#  'performance',
#  'pergudangan',
#  'perhari',
#  'perhatian',
#  'perhitungan',
#  'perilaku',
#  'perindustrian',
#  'periode',
#  'perkembangan',
#  'perlu',
#  'permainan',
#  'permasalahan',
#  'permintaan',
#  'peroleh',
#  'perolehan',
#  'persaingan',
#  'persamaan',
#  'persediaan',
#  'persentase',
#  'persero',
#  'pertama',
#  'pertanian',
#  'pertumbuhan',
#  'perubahan',
#  'perusahaan',
#  'pesan',
#  'pesat',
#  'peternakan',
#  'pihak',
#  'piksel',
#  'pixel',
#  'plagiarisme',
#  'plastec',
#  'platform',
#  'player',
#  'point',
#  'pola',
#  'pose',
#  'prediksi',
#  'preshion',
#  'prim',
#  'principal',
#  'prioritas',
#  'probabilitas',
#  'process',
#  'produk',
#  'produksi',
#  'produktivitas',
#  'program',
#  'programming',
#  'promosi',
#  'prose',
#  'prosentase',
#  'proses',
#  'proxy',
#  'proyek',
#  'pulau',
#  'puskesmas',
#  'quantity',
#  'quantization',
#  'query',
#  'radial',
#  'rangka',
#  'raskin',
#  'rata',
#  'rate',
#  'rbf',
#  'real',
#  'reality',
#  'recognition',
#  'region',
#  'rekayasa',
#  'rekomendasi',
#  'rencana',
#  'rendah',
#  'resolusi',
#  'resource',
#  'respon',
#  'responden',
#  'rule',
#  'rumah',
#  'rumput',
#  'saat',
#  'sakit',
#  'salah',
#  'sampai',
#  'sampang',
#  'sangat',
#  'sangatlah',
#  'sapi',
#  'sarana',
#  'satu',
#  'satunya',
#  'scale',
#  'scorecard',
#  'scoring',
#  'screen',
#  'sdlc',
#  'search',
#  'sebagai',
#  'sebagian',
#  'sebaliknya',
#  'sebanyak',
#  'sebelumnya',
#  'sebesar',
#  'sebuah',
#  'secara',
#  'second',
#  'sedang',
#  'sedangkan',
#  'sedikit',
#  'segmentasi',
#  'sehingga',
#  'seiring',
#  'sejak',
#  'sekumpulan',
#  'selain',
#  'selama',
#  'selanjutnya',
#  'seleksi',
#  'self',
#  'selisih',
#  'seluas',
#  'seluruh',
#  'seluruhnya',
#  'semakin',
#  'semantic',
#  'semantik',
#  'sembilan',
#  'semua',
#  'sendiri',
#  'seni',
#  'senyum',
#  'senyuman',
#  'seorang',
#  'sepanjang',
#  'separation',
#  'seperti',
#  'sepuluh',
#  'serangan',
#  'series',
#  'sering',
#  'seringkali',
#  'serta',
#  'server',
#  'service',
#  'seseorang',
#  'sesuai',
#  'setelah',
#  'setiap',
#  'siakad',
#  'sidik',
#  'sift',
#  'similaritas',
#  'similarity',
#  'simulasi',
#  'single',
#  'sistem',
#  'siswa',
#  'skala',
#  'skenario',
#  'smarter',
#  'smartphone',
#  'smoothing',
#  'snort',
#  'soal',
#  'soalnya',
#  'software',
#  'solo',
#  'solusi',
#  'solusinya',
#  'som',
#  'sort',
#  'source',
#  'spare',
#  'spci',
#  'speech',
#  'spesifikasi',
#  'square',
#  'stakeholder',
#  'standar',
#  'state',
#  'statistik',
#  'status',
#  'stok',
#  'strategy',
#  'straw',
#  'studi',
#  'suatu',
#  'sudah',
#  'sulit',
#  'sumber',
#  'sumenep',
#  'supaya',
#  'supplier',
#  'supply',
#  'surabaya',
#  'swarm',
#  'syaraf',
#  'system',
#  'tahap',
#  'tahapan',
#  'tahun',
#  'taman',
#  'tampilan',
#  'tanah',
#  'tanaman',
#  'tangan',
#  'tanpa',
#  'target',
#  'technique',
#  'teknik',
#  'teknis',
#  'teknologi',
#  'teks',
#  'tekstur',
#  'telah',
#  'telapak',
#  'tempat',
#  'tengah',
#  'tentang',
#  'tentukan',
#  'tentunya',
#  'tepat',
#  'tepi',
#  'terbaik',
#  'terbaru',
#  'terbentuk',
#  'terbesar',
#  'terdapat',
#  'terdeteksi',
#  'terdiri',
#  'terdistribusi',
#  'terendah',
#  'terenkripsi',
#  'terhadap',
#  'terjadi',
#  'terjadinya',
#  'terkecil',
#  'terlalu',
#  'terlebih',
#  'terpisah',
#  'terpusat',
#  'tersebut',
#  'tersedia',
#  'tersimpan',
#  'tertentu',
#  'tertinggi',
#  'terus',
#  'terutama',
#  'tes',
#  'test',
#  'testing',
#  'tetap',
#  'tetapi',
#  'threshold',
#  'tiap',
#  'tidak',
#  'tiga',
#  'time',
#  'tindakan',
#  'tinggi',
#  'tingkat',
#  'tinta',
#  'tipe',
#  'tiruan',
#  'titik',
#  'toefl',
#  'togaf',
#  'toko',
#  'tool',
#  'topsis',
#  'traffic',
#  'training',
#  'transaksi',
#  'transform',
#  'transformasi',
#  'trunojoyo',
#  'tsai',
#  'tubuh',
#  'tugas',
#  'tujuan',
#  'tulis',
#  'tulisan',
#  'tunggal',
#  'ujicoba',
#  'umum',
#  'umumnya',
#  'unggulan',
#  'unik',
#  'universitas',
#  'untuk',
#  'upaya',
#  'usaha',
#  'user',
#  'utama',
#  'variasinya',
#  'vector',
#  'video',
#  'virtual',
#  'vision',
#  'visualisasi',
#  'wachid',
#  'wajah',
#  'waktu',
#  'waterfall',
#  'watershed',
#  'wavelet',
#  'website',
#  'wilayah',
#  'window',
#  'winnowing',
#  'yaitu',
#  'yakni',
#  'yang',
#  'yogyakarta']

# %%
vect_text.todense()
# Out:
# matrix([[0.        , 0.06758881, 0.        , ..., 0.        , 0.10364702,
#          0.        ],
#         [0.        , 0.05567105, 0.        , ..., 0.        , 0.1707424 ,
#          0.        ],
#         [0.        , 0.07377258, 0.        , ..., 0.        , 0.16969468,
#          0.        ],
#         ...,
#         [0.        , 0.        , 0.        , ..., 0.        , 0.04222837,
#          0.        ],
#         [0.        , 0.02123406, 0.03708292, ..., 0.        , 0.04884344,
#          0.        ],
#         [0.        , 0.02092204, 0.03653803, ..., 0.        , 0.12833528,
#          0.        ]])

# %%
df = pd.DataFrame(vect_text.todense().T, index=vect.get_feature_names(), columns=[f'{i+1}' for i in range (len(df))])
df
# Out:
#                       1         2         3         4         5         6  \
# abstrak        0.000000  0.000000  0.000000  0.000000  0.057065  0.000000
# adalah         0.067589  0.055671  0.073773  0.048564  0.021256  0.000000
# adanya         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# administrator  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# agar           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# akademik       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# akan           0.025911  0.000000  0.000000  0.083780  0.000000  0.000000
# akhir          0.000000  0.000000  0.000000  0.044736  0.000000  0.000000
# aksara         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# akurasi        0.039345  0.000000  0.000000  0.000000  0.037121  0.000000
# akurat         0.000000  0.000000  0.000000  0.000000  0.057065  0.000000
# algoritma      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# alternatif     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# analisa        0.000000  0.070839  0.000000  0.000000  0.054094  0.000000
# analisis       0.000000  0.149461  0.066019  0.000000  0.000000  0.000000
# analysis       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# analytic       0.000000  0.000000  0.000000  0.061796  0.000000  0.000000
# android        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# angular        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# animasi        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# antar          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# antara         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# apabila        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# aplikasi       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# arah           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# arosbaya       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# arsitektur     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# asesoris       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# aspek          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# atas           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...                 ...       ...       ...       ...       ...       ...
# umum           0.000000  0.000000  0.070227  0.000000  0.000000  0.000000
# umumnya        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# unggulan       0.000000  0.000000  0.151302  0.000000  0.000000  0.000000
# unik           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# universitas    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# untuk          0.053551  0.066163  0.038967  0.057717  0.067364  0.109013
# upaya          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# usaha          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# user           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# utama          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# variasinya     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# vector         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# video          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# virtual        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# vision         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# visualisasi    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# wachid         0.000000  0.000000  0.000000  0.000000  0.215996  0.000000
# wajah          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# waktu          0.000000  0.062185  0.000000  0.000000  0.000000  0.000000
# waterfall      0.069310  0.000000  0.075651  0.000000  0.000000  0.000000
# watershed      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# wavelet        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# website        0.415859  0.000000  0.151302  0.000000  0.000000  0.000000
# wilayah        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# window         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# winnowing      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# yaitu          0.064012  0.000000  0.069868  0.000000  0.000000  0.000000
# yakni          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# yang           0.103647  0.170742  0.169695  0.055855  0.097786  0.123079
# yogyakarta     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#                       7         8         9        10  ...        51  \
# abstrak        0.000000  0.000000  0.000000  0.000000  ...  0.000000
# adalah         0.000000  0.014967  0.000000  0.000000  ...  0.051856
# adanya         0.000000  0.000000  0.078346  0.000000  ...  0.000000
# administrator  0.000000  0.000000  0.000000  0.000000  ...  0.000000
# agar           0.000000  0.000000  0.000000  0.000000  ...  0.000000
# akademik       0.000000  0.000000  0.000000  0.000000  ...  0.000000
# akan           0.000000  0.034426  0.025797  0.000000  ...  0.029819
# akhir          0.051588  0.027574  0.000000  0.000000  ...  0.000000
# aksara         0.000000  0.000000  0.000000  0.000000  ...  0.000000
# akurasi        0.048901  0.026138  0.000000  0.000000  ...  0.000000
# akurat         0.000000  0.000000  0.000000  0.000000  ...  0.000000
# yaitu          0.119336  0.063786  0.127461  0.000000  ...  0.073667
# yakni          0.000000  0.000000  0.000000  0.000000  ...  0.000000
# yang           0.107348  0.022952  0.120391  0.113494  ...  0.079521
# yogyakarta     0.000000  0.000000  0.000000  0.000000  ...  0.000000
#
#                      52        53        54        55        56        57  \
# abstrak        0.000000  0.054172  0.000000  0.000000  0.000000  0.000000
# adalah         0.000000  0.020178  0.036473  0.000000  0.034302  0.023376
# adanya         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# administrator  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# agar           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# akademik       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# akan           0.059037  0.023207  0.000000  0.000000  0.039450  0.000000
# akhir          0.000000  0.037175  0.067196  0.000000  0.000000  0.000000
# aksara         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# akurasi        0.000000  0.000000  0.000000  0.000000  0.029952  0.040823
# akurat         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# algoritma      0.059657  0.140702  0.000000  0.241161  0.000000  0.000000
# alternatif     0.000000  0.000000  0.000000  0.074076  0.000000  0.000000
# analisa        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# analisis       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# analysis       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# analytic       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# android        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# angular        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# animasi        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# antar          0.000000  0.288124  0.000000  0.000000  0.000000  0.000000
# antara         0.000000  0.000000  0.000000  0.053957  0.000000  0.000000
# apabila        0.068907  0.000000  0.000000  0.069638  0.000000  0.062757
# aplikasi       0.000000  0.087816  0.105821  0.000000  0.000000  0.000000
# arah           0.000000  0.000000  0.000000  0.000000  0.046045  0.000000
# arosbaya       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# arsitektur     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# asesoris       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# aspek          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# atas           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ...                 ...       ...       ...       ...       ...       ...
# umum           0.000000  0.000000  0.000000  0.074076  0.000000  0.000000
# umumnya        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# unggulan       0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# unik           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# universitas    0.000000  0.000000  0.000000  0.069638  0.000000  0.000000
# untuk          0.020336  0.047962  0.072244  0.020551  0.095121  0.037041
# upaya          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# usaha          0.000000  0.000000  0.000000  0.000000  0.105525  0.000000
# user           0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# utama          0.000000  0.000000  0.046410  0.000000  0.000000  0.000000
# variasinya     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# vector         0.000000  0.000000  0.000000  0.000000  0.174283  0.000000
# video          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# virtual        0.000000  0.000000  0.364557  0.000000  0.000000  0.000000
# vision         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# visualisasi    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# wachid         0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# wajah          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# waktu          0.000000  0.000000  0.000000  0.115895  0.000000  0.000000
# waterfall      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# watershed      0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# wavelet        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# website        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# wilayah        0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# window         0.000000  0.136698  0.000000  0.000000  0.000000  0.000000
# winnowing      0.000000  0.136698  0.000000  0.000000  0.000000  0.000000
# yaitu          0.000000  0.114661  0.051814  0.036849  0.000000  0.066415
# yakni          0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# yang           0.098398  0.092829  0.083896  0.139218  0.118353  0.161308
# yogyakarta     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#                      58        59        60
# abstrak        0.000000  0.000000  0.000000
# adalah         0.000000  0.021234  0.020922
# adanya         0.000000  0.037083  0.036538
# administrator  0.000000  0.000000  0.000000
# agar           0.000000  0.103058  0.000000
# akademik       0.000000  0.000000  0.000000
# akan           0.000000  0.048842  0.024062
# akhir          0.000000  0.000000  0.000000
# aksara         0.000000  0.000000  0.000000
# akurasi        0.000000  0.000000  0.036538
# akurat         0.000000  0.000000  0.000000
# algoritma      0.000000  0.000000  0.000000
# alternatif     0.000000  0.000000  0.000000
# analisa        0.000000  0.000000  0.000000
# analisis       0.000000  0.000000  0.000000
# analysis       0.046720  0.000000  0.000000
# analytic       0.000000  0.000000  0.000000
# android        0.000000  0.000000  0.000000
# angular        0.000000  0.000000  0.000000
# animasi        0.000000  0.000000  0.000000
# antar          0.000000  0.000000  0.000000
# antara         0.000000  0.000000  0.000000
# apabila        0.000000  0.000000  0.000000
# aplikasi       0.026632  0.123216  0.060703
# arah           0.000000  0.000000  0.000000
# arosbaya       0.000000  0.000000  0.000000
# arsitektur     0.000000  0.653242  0.000000
# asesoris       0.000000  0.000000  0.000000
# aspek          0.000000  0.051529  0.000000
# atas           0.000000  0.000000  0.000000
# ...                 ...       ...       ...
# umum           0.000000  0.000000  0.000000
# umumnya        0.000000  0.000000  0.000000
# unggulan       0.000000  0.000000  0.000000
# unik           0.052428  0.000000  0.000000
# universitas    0.000000  0.000000  0.000000
# untuk          0.014545  0.033648  0.033153
# upaya          0.000000  0.000000  0.000000
# usaha          0.000000  0.000000  0.000000
# user           0.000000  0.000000  0.000000
# utama          0.000000  0.054039  0.000000
# variasinya     0.000000  0.000000  0.000000
# vector         0.000000  0.000000  0.000000
# video          0.000000  0.000000  0.000000
# virtual        0.000000  0.000000  0.000000
# vision         0.000000  0.000000  0.000000
# visualisasi    0.000000  0.000000  0.000000
# wachid         0.000000  0.000000  0.000000
# wajah          0.000000  0.000000  0.000000
# waktu          0.000000  0.000000  0.000000
# waterfall      0.000000  0.000000  0.000000
# watershed      0.000000  0.000000  0.000000
# wavelet        0.000000  0.000000  0.000000
# website        0.000000  0.000000  0.000000
# wilayah        0.000000  0.000000  0.000000
# window         0.000000  0.000000  0.000000
# winnowing      0.000000  0.000000  0.000000
# yaitu          0.000000  0.000000  0.000000
# yakni          0.000000  0.000000  0.000000
# yang           0.042228  0.048843  0.128335
# yogyakarta     0.000000  0.000000  0.000000
#
# [1000 rows x 60 columns]

# %% [markdown]
# # LSA

# %%
idf=vect.idf_

# %%
dd=dict(zip(vect.get_feature_names(), idf))
l=sorted(dd, key=(dd).get)
# print(l)
print(l[0],l[-1])
print(dd['yang'])
print(dd['wajah'])  # police is most common and forecast is least common among the news headlines.
# Out:
# yang yakni
# 1.0
# 4.417726683613366

# %%
from sklearn.decomposition import TruncatedSVD
lsa_model = TruncatedSVD(n_components=10, algorithm='randomized', n_iter=10, random_state=42)

lsa_top=lsa_model.fit_transform(vect_text)

# %% [markdown]
# Mirip dengan dokumen lain kita bisa melakukan ini. Namun perhatikan bahwa nilai tidak menambah 1 seperti di LSA itu bukan kemungkinan topik dalam dokumen.

# %%
print(lsa_top)
print(lsa_top.shape)  # (no_of_doc*no_of_topics)
# Out:
# [[ 2.93195838e-01  8.84092663e-03 -7.29179826e-02  1.17069965e-01
#   -1.82658458e-01 -1.27523179e-01  6.95203298e-03 -6.76797920e-02
#    5.45971227e-01  3.26196439e-01]
#  [ 3.09718936e-01 -1.09188837e-01 -1.21164223e-01 -7.92800026e-02
#  [ 2.92717415e-01 -1.31334771e-01 -1.16940837e-01 -2.62236544e-02
#    6.21502049e-02  6.26730661e-01  8.13650564e-03 -2.45332524e-01
#   -1.72832186e-01  2.69012341e-01]]
# (60, 10)

# %%
l=lsa_top[0]
print("Document 0 :")
for i,topic in enumerate(l):
  print("Topic ",i," : ",topic*100)
# Out:
# Document 0 :
# Topic  0  :  29.319583787158866
# Topic  1  :  0.8840926628748778
# Topic  2  :  -7.291798255600251
# Topic  3  :  11.706996457454508
# Topic  4  :  -18.265845810754445
# Topic  5  :  -12.752317934641852
# Topic  6  :  0.6952032977929073
# Topic  7  :  -6.767979198740753
# Topic  8  :  54.59712272352628
# Topic  9  :  32.61964393497524

# %%
print(lsa_model.components_.shape) # (no_of_topics*no_of_words)
print(lsa_model.components_)
# Out:
# (10, 1000)
# [[ 1.29193139e-02  9.32641786e-02  4.29301048e-02 ...  2.98707406e-03
#    3.78743847e-01  1.12498403e-02]
#  [-7.54606722e-03 -2.85748615e-02 -2.45386036e-02 ... -4.37847788e-03
#   -8.93893479e-02  2.80826261e-02]
#  [ 1.09778106e-02  2.06694806e-02  6.29381658e-03 ...  1.49348024e-03
#   -3.74529931e-02  8.96205721e-04]
#  ...
#  [ 3.51803765e-02  2.41140910e-02  2.40699528e-02 ...  4.26242623e-03
#    5.95864199e-02 -5.84555018e-03]
#  [ 7.52963909e-03  5.17529132e-02 -3.12128680e-02 ... -6.84498590e-03
#    5.71438094e-02  3.52410458e-03]
#  [ 5.99312487e-03  4.31766775e-02 -5.68801061e-03 ... -1.38439683e-04
#   -4.05730679e-02  9.30229787e-03]]

# %% [markdown]
# Sekarang bisa mendapatkan daftar kata-kata penting dari masing-masing untuk 10 topik seperti yang ditunjukkan. Untuk kesederhanaan di sini saya telah menunjukkan 10 kata untuk setiap topik

# %%
# most important words for each topic
vocab = vect.get_feature_names()

for i, comp in enumerate(lsa_model.components_):
    vocab_comp = zip(vocab, comp)
    sorted_words = sorted(vocab_comp, key= lambda x:x[1], reverse=True)[:10]
    print("Topic "+str(i)+": ")
    for t in sorted_words:
        print(t[0],end=" ")
    print("\n")
# Out:
# Topic 0:
# yang citra dengan pada untuk dari metode sistem dalam data
#
# Topic 1:
# citra tulisan tangan pengenalan batik fitur ekstraksi tekstur ciri wajah
#
# Topic 2:
# game mobile pembelajaran android teknologi gerakan sapi virtual reality algoritma
#
# Topic 3:
# arsitektur enterprise bangkalan togaf citra batik informasi dinas pelayanan tahapan
#
# Topic 4:
# tangan arsitektur tulisan pengenalan telapak enterprise togaf sistem bangkalan informasi
#
# Topic 5:
# gizi status pasien balita makanan keputusan pendukung menu bayes naïve
#
# Topic 6:
# kriteria reality karyawan virtual keputusan pendukung augmented teknologi tangan dunia
#
# Topic 7:
# reality virtual dokumen augmented dunia second life hujan penjadwalan teknologi
#
# Topic 8:
# batik website commerce tulis decision model toko madura penjadwalan kuliah
#
# Topic 9:
# batik gizi reality status commerce virtual peramalan website tulis penjualan
